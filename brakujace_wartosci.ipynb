# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Brakujące wartości**
#
# **Brakujące wartości** to rekordy, które są nieobecne w zestawie danych.
#
# **Przyczyny występowania**:
# * Błąd człowieka podczas wprowadzania danych​
#
# * Ochrona prywatności (dane wrażliwe)
# * Brak odpowiedzi w ankietach
#
# Problemy techniczne przy zbieraniu danych
#
# Jest to jeden z **najczęściej występujących problemów** w analizie danych i kluczowy etap wstępnego przetwarzania (data preprocessing).

# %%
# Definicja DataFrame
df_student = pd.DataFrame({
    'imie': ['Anna', 'Piotr', 'Maria', 'Jan', 'Katarzyna', 'Tomasz', 'Magdalena', 'Paweł', 'Ewa', 'Michał'],
    'wiek': [20, 22, 21, np.nan, 23, 20, 22, np.nan, 21, 23],
    'ocena_matematyka': [4.5, np.nan, 5.0, 4.0, 3.5, 4.5, 5.0, 3.5, np.nan, 4.0],
    'ocena_fizyka': [5.0, 4.5, np.nan, 4.0, 4.5, np.nan, 5.0, 4.0, 4.5, np.nan],
    'ocena_informatyka': [4.0, 3.5, 4.5, np.nan, 5.0, 3.5, 4.5, 4.0, np.nan, 4.5],
    'miasto': ['Warszawa', 'Kraków', 'Wrocław', 'Poznań', 'Gdańsk', np.nan, 'Warszawa', 'Kraków', 'Wrocław', 'Poznań']
})

# %%
# 1. Sprawdzenie czy są brakujące wartości
print("1. Sprawdzenie brakujących wartości (True = brak):")
print(df_student.isnull())
# lub: df.isna()
print("\n" + "="*60 + "\n")
# Out:
# 1. Sprawdzenie brakujących wartości (True = brak):
#     imie   wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  miasto
# 0  False  False             False         False              False   False
# 1  False  False              True         False              False   False
# 2  False  False             False          True              False   False
# 3  False   True             False         False               True   False
# 4  False  False             False         False              False   False
# 5  False  False             False          True              False    True
# 6  False  False             False         False              False   False
# 7  False   True             False         False              False   False
# 8  False  False              True         False               True   False
# 9  False  False             False          True              False   False
#
# ============================================================

# %%
# 2. Liczba brakujących wartości w każdej kolumnie
print("2. Liczba brakujących wartości w każdej kolumnie:")
print(df_student.isna().sum())
print("\n" + "="*60 + "\n")
# Out:
# 2. Liczba brakujących wartości w każdej kolumnie:
# imie                 0
# wiek                 2
# ocena_matematyka     2
# ocena_fizyka         3
# ocena_informatyka    2
# miasto               1
# dtype: int64
#
# ============================================================

# %%
# 3. Procent brakujących wartości
print("3. Procent brakujących wartości w każdej kolumnie:")
print((df_student.isnull().sum() / len(df)) * 100)
print("\n" + "="*60 + "\n")
# Out:
# 3. Procent brakujących wartości w każdej kolumnie:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1383876763.py in <cell line: 0>()
#       1 # 3. Procent brakujących wartości
#       2 print("3. Procent brakujących wartości w każdej kolumnie:")
# ----> 3 print((df_student.isnull().sum() / len(df)) * 100)
#       4 print("\n" + "="*60 + "\n")
#
# NameError: name 'df' is not defined

# %%
# 4. Całkowita liczba brakujących wartości
print("4. Całkowita liczba brakujących wartości w całym DataFrame:")
print(df_student.isnull().sum().sum())

# %% [markdown]
# ## **Rozwiązanie kwestii brakujących danych**
#
# * **Usuwanie rekordów** zawierających brakujące wartości.
# * **Ręczne uzupełnianie** brakujących wartości.
# * Uzupełnianie **brakujących wartości wskaźnikami** tendencji centralnej, np.: średnią, medianą czy dominantą.
#   * **Średniej** używamy w przypadku cech numerycznych,
#   * **mediany** w cechach porządkowych,
#   * **dominantę** (czyli najczęściej powtarzającą się wartość) umieszczamy w cechach kategorialnych.
#
# Uzupełnianie **najbardziej prawdopodobną wartością** przy użyciu modeli uczenia maszynowego, takich jak regresja, drzewa decyzyjne czy algorytm KNN.

# %% [markdown]
# ## **Czym jest NaN i dlaczego jest wyjątkowy?**
#
# **NaN** (Not a Number) – specjalna wartość reprezentująca brakujące dane.
#
# Dane mogą zawierać różne oznaczenia braków:
# * Tekstowe: "NA", "N/A", "brak", "?", "-"
#
# * Numeryczne: 0, -999, -1​
#
# * Inne: puste stringi ""

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %% [markdown]
#  Dlatego używamy specjalnych funkcji:

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
df = pd.DataFrame({
    'A': [1, np.nan, 3],# ✓ NaN - brakująca wartość ​
    'B': [4, None, 6],  # ✓ None - też brakująca ​
    'C': [7, 0, 9],     # ✗ 0 - NIE jest brakująca! ​
    'D': ['x', '', 'z'] # ✗ '' - NIE jest brakująca! ​
})

# %%
df.isnull().sum()
# Out:
# A    1
# B    1
# C    0
# D    0
# dtype: int64

# %% [markdown]
# ## **Usuwanie brakujących wartości**
#
# Usuń wiersze z DOWOLNĄ brakującą wartością (domyślnie) ​
#
# ```
# df.dropna()
# df.dropna(how='any')
# ```
#
# Usuń wiersze tylko gdy WSZYSTKIE wartości są brakujące df.dropna(how='all')
# ```
# df.dropna(how="all")
# ```
#
# Usuń kolumny z brakującymi wartościami
# ```
# df.dropna(axis=1)
# ```

# %% [markdown]
# ## **Uzupełnienie średnią lub modą​**
#
# W pandas *dataFrame* możemy uzupełnić brakujące wartości za pomocą funkcji `fillna()`.
# * Przyjmuje ona jedną wartość, która będzie wstawiana w pustych pozycjach lub zamiast wartości NaN.

# %% [markdown]
# Uzupełnia wszystkie brakujące wartości w kolumnie age średnią obliczoną z tejże kolumny
#
# ```data['age'] = data.age.fillna(data.age.mean())​```
#
# Uzupełnia wszystkie brakujące wartości w kolumnie income medianą obliczoną z tejże kolumny
#
# ```data['income']=data.income.fillna(data.income.median())```
#
# Zastępuje wszystkie brakujące wartości w kolumnie gender (kolumna kategorii) dominantą wyliczoną z tejże kolumny​
#
# ```data['gender']=data['gender'].fillna(data['gender'].mode()[0])​```

# %%
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0               4.5           5.0                4.0
# 1      Piotr  22.0               NaN           4.5                3.5
# 2      Maria  21.0               5.0           NaN                4.5
# 3        Jan   NaN               4.0           4.0                NaN
# 4  Katarzyna  23.0               3.5           4.5                5.0
# 5     Tomasz  20.0               4.5           NaN                3.5
# 6  Magdalena  22.0               5.0           5.0                4.5
# 7      Paweł   NaN               3.5           4.0                4.0
# 8        Ewa  21.0               NaN           4.5                NaN
# 9     Michał  23.0               4.0           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5       NaN
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %%
df_student["wiek"] = df_student.wiek.fillna(df_student.wiek.mean())
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0               4.5           5.0                4.0
# 1      Piotr  22.0               NaN           4.5                3.5
# 2      Maria  21.0               5.0           NaN                4.5
# 3        Jan  21.5               4.0           4.0                NaN
# 4  Katarzyna  23.0               3.5           4.5                5.0
# 5     Tomasz  20.0               4.5           NaN                3.5
# 6  Magdalena  22.0               5.0           5.0                4.5
# 7      Paweł  21.5               3.5           4.0                4.0
# 8        Ewa  21.0               NaN           4.5                NaN
# 9     Michał  23.0               4.0           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5       NaN
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %%
df_student["ocena_matematyka"] = df_student["ocena_matematyka"] .fillna(df_student["ocena_matematyka"] .mean())
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0              4.50           5.0                4.0
# 1      Piotr  22.0              4.25           4.5                3.5
# 2      Maria  21.0              5.00           NaN                4.5
# 3        Jan  21.5              4.00           4.0                NaN
# 4  Katarzyna  23.0              3.50           4.5                5.0
# 5     Tomasz  20.0              4.50           NaN                3.5
# 6  Magdalena  22.0              5.00           5.0                4.5
# 7      Paweł  21.5              3.50           4.0                4.0
# 8        Ewa  21.0              4.25           4.5                NaN
# 9     Michał  23.0              4.00           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5       NaN
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %%
df_student["miasto"] = df_student["miasto"].fillna(df_student["miasto"] .mode()[0])
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0              4.50           5.0                4.0
# 1      Piotr  22.0              4.25           4.5                3.5
# 2      Maria  21.0              5.00           NaN                4.5
# 3        Jan  21.5              4.00           4.0                NaN
# 4  Katarzyna  23.0              3.50           4.5                5.0
# 5     Tomasz  20.0              4.50           NaN                3.5
# 6  Magdalena  22.0              5.00           5.0                4.5
# 7      Paweł  21.5              3.50           4.0                4.0
# 8        Ewa  21.0              4.25           4.5                NaN
# 9     Michał  23.0              4.00           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5    Kraków
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %% [markdown]
# ## **Obsługa brakujących danych jako stringi**
#
# **Problem**
# * Dane często zawierają braki zapisane jako tekst: **"NA", "N/A", "brak", "?", "-", "brak danych"**
#
# * Pandas **nie rozpoznaje** ich automatycznie jako brakujące wartości!

# %% [markdown]
# ### **Rozwiązanie 1: Wczytywanie z pliku CSV**
#
# ```
# import pandas as pd
#
# # Definiujemy listę wartości oznaczających brak
# braki = ['NA', 'N/A', 'brak', 'brak danych', '?', '-', '']
#
# # Wczytujemy plik z parametrem na_values
# df = pd.read_csv('dane.csv', na_values=braki)
#
# ```

# %% [markdown]
# ### **Rozwiązanie 2: Zamiana po wczytaniu**

# %% [markdown]
# ```
# # Zamieniamy wybrane stringi na NaN
# df.replace(['NA', 'N/A', 'brak', 'brak danych', '?', '-'], np.nan, inplace=True)
#
# # LUB dla konkretnej kolumny
# df['kolumna'] = df['kolumna'].replace('brak', np.nan)
# ```

# %% [markdown]
# # **Zadanie**:
#
# **Dane**: Plik *nieruchomosci.csv* - 45 ofert sprzedaży mieszkań
#
# **Polecenie**
#
# * Wczytaj dane i przeanalizuj problem brakujących wartości
#
# * Zdecyduj, jak poradzić sobie z brakami w poszczególnych kolumnach
#
# * Uzasadnij swoje wybory i zaimplementuj rozwiązanie
#
# **Do przemyślenia**
#
# * Jakie typy zmiennych masz w danych?
# * Czy wszystkie braki powinny być obsłużone tak samo?
# * Jakie konsekwencje niesie każda metoda?
# * Jak to wpływa na eksploracyjną analizę danych?

# %%
import matplotlib.pyplot as plt

braki = ['NA', 'N/A', 'brak', 'brak danych', '?', '-', '', "-999", "-1", "很好" ,"0"]
df = pd.read_csv("nieruchomosci.csv", na_values=braki, index_col=0)


#Powierzchnia może zostać ustalona na podstwie ceny i ceny za m2
df["powierzchnia"] = df["powierzchnia"].fillna(df["cena_total"]/df["cena_m2"])
#Podobnie z ceną za m2
df["cena_m2"] = df["cena_m2"].fillna(df["cena_total"]/df["powierzchnia"])

#Pozostałe uzupełniam dominantom
df["rok_budowy"] = df["rok_budowy"].fillna(df["rok_budowy"].mode()[0])
df["pietro"] = df["pietro"].fillna(df["pietro"].mode()[0])
df["parking"] = df["parking"].fillna(df["parking"].mode()[0])
df["balkon"] = df["balkon"].fillna(df["balkon"].mode()[0])
df["stan"] = df["stan"].fillna(df["stan"].mode()[0])

df
# Out:
#       miasto      dzielnica  powierzchnia  liczba_pokoi  rok_budowy  pietro  \
# id
# 1   Warszawa        Mokotów          65.0             3      2015.0     4.0
# 2     Kraków      Krowodrza          48.0             2      2010.0     2.0
# 3    Wrocław         Krzyki          72.0             3      2010.0     2.0
# 4     Poznań       Grunwald          55.0             2      2018.0     3.0
# 5     Gdańsk       Wrzeszcz          80.0             4      1998.0     1.0
# 6   Warszawa    Śródmieście          80.0             2      2020.0     7.0
# 7     Kraków       Podgórze          60.0             3      2005.0     2.0
# 8    Wrocław   Stare Miasto          45.0             1      2019.0     5.0
# 9     Poznań         Jeżyce          70.0             3      2010.0     2.0
# 10    Gdańsk          Oliwa          90.0             4      2001.0     1.0
# 11  Warszawa       Żoliborz          58.0             2      2016.0     2.0
# 12    Kraków      Kazimierz          52.0             2      1995.0     3.0
# 13   Wrocław      Psie Pole          68.0             3      2012.0     4.0
# 14    Poznań         Rataje          60.0             2      2017.0     6.0
# 15    Gdańsk        Siedlce          75.0             3      2010.0     2.0
# 16  Warszawa          Praga          62.0             3      2014.0     3.0
# 17    Kraków      Nowa Huta          50.0             2      2008.0     1.0
# 18   Wrocław      Fabryczna          70.0             4      2011.0     2.0
# 19    Poznań          Wilda          66.0             3      1999.0     4.0
# 20    Gdańsk      Przymorze          85.0             4      2003.0     2.0
# 21  Warszawa         Ochota          54.0             2      2010.0     5.0
# 22    Kraków      Bronowice          60.0             3      2013.0     2.0
# 23   Wrocław         Krzyki          70.0             3      2009.0     3.0
# 24    Poznań        Centrum          48.0             1      2021.0     8.0
# 25    Gdańsk    Śródmieście          95.0             5      1997.0     1.0
# 26  Warszawa        Ursynów          60.0             2      2015.0     4.0
# 27    Kraków        Dębniki          56.0             2      2010.0     1.0
# 28   Wrocław   Stare Miasto          42.0             1      2020.0     6.0
# 29    Poznań       Grunwald          60.0             3      2007.0     2.0
# 30    Gdańsk          Zaspa          78.0             3      2002.0     3.0
# 31  Warszawa        Wilanów          88.0             4      2018.0     2.0
# 32    Kraków     Łagiewniki          60.0             2      2016.0     4.0
# 33   Wrocław       Biskupin          64.0             3      2011.0     1.0
# 34    Poznań         Sołacz          72.0             3      1996.0     2.0
# 35    Gdańsk          Chełm          80.0             4      2014.0     2.0
# 36  Warszawa        Bielany          58.0             2      2010.0     5.0
# 37    Kraków         Ruczaj          51.0             2      2019.0     3.0
# 38   Wrocław            Gaj          69.0             3      2006.0     4.0
# 39    Poznań         Główna          46.0             1      2022.0     7.0
# 40    Gdańsk         Morena          82.0             4      2000.0     1.0
# 41  Warszawa       Targówek          62.0             3      2013.0     2.0
# 42    Kraków  Mistrzejowice          60.0             2      2017.0     6.0
# 43   Wrocław          Ołbin          55.0             2      2010.0     3.0
# 44    Poznań       Piątkowo          65.0             3      2010.0     1.0
# 45    Gdańsk      Suchanino          76.0             3      2004.0     2.0
#
#     liczba_pieter parking balkon          stan       cena_m2  cena_total
# id
# 1              10     Tak    Tak         Dobry  12500.000000      812500
# 2               5     Nie    Tak         Dobry  10200.000000      489600
# 3               4     Tak    Nie         Dobry   9800.000000      705600
# 4               8     Tak    Tak  Bardzo dobry  11000.000000      605000
# 5               3     Tak    Tak    Do remontu   8500.000000      680000
# 6              12     Tak    Tak  Bardzo dobry  15000.000000     1200000
# 7               6     Tak    Nie         Dobry   9500.000000      570000
# 8               9     Nie    Tak  Bardzo dobry  11500.000000      517500
# 9               4     Tak    Tak         Dobry  10500.000000      735000
# 10              2     Tak    Tak         Dobry   9000.000000      810000
# 11              7     Tak    Tak         Dobry  13000.000000      754000
# 12              4     Nie    Tak    Do remontu   9000.000000      468000
# 13             10     Tak    Tak         Dobry   8800.000000      598400
# 14             11     Tak    Tak  Bardzo dobry  10800.000000      648000
# 15              5     Tak    Tak         Dobry   8700.000000      652500
# 16              8     Tak    Nie         Dobry  11500.000000      713000
# 17              4     Tak    Tak         Dobry   8500.000000      425000
# 18              3     Tak    Tak         Dobry   9200.000000      644000
# 19              5     Nie    Tak    Do remontu   9000.000000      594000
# 20              6     Tak    Tak         Dobry   8900.000000      756500
# 21              9     Tak    Tak  Bardzo dobry  12800.000000      691200
# 22              7     Tak    Nie         Dobry   9800.000000      588000
# 23              8     Tak    Tak         Dobry   9300.000000      651000
# 24             15     Tak    Tak  Bardzo dobry  12500.000000      600000
# 25              3     Tak    Tak    Do remontu   8200.000000      779000
# 26             11     Tak    Tak         Dobry  11800.000000      708000
# 27              4     Tak    Tak         Dobry   9600.000000      537600
# 28             10     Nie    Tak  Bardzo dobry  12000.000000      504000
# 29              5     Tak    Tak         Dobry  10200.000000      612000
# 30              9     Tak    Nie         Dobry   8400.000000      655200
# 31              6     Tak    Tak  Bardzo dobry  14000.000000     1232000
# 32              8     Tak    Tak         Dobry   9400.000000      564000
# 33              4     Tak    Tak         Dobry   9700.000000      620800
# 34              2     Tak    Tak    Do remontu   9800.000000      705600
# 35              7     Tak    Tak         Dobry   8800.000000      704000
# 36             10     Tak    Nie         Dobry  11200.000000      649600
# 37              9     Tak    Tak  Bardzo dobry  10500.000000      535500
# 38              5     Nie    Tak         Dobry   8900.000000      614100
# 39             12     Tak    Tak  Bardzo dobry  12500.000000      575000
# 40              4     Tak    Tak         Dobry   8895.121951      729400
# 41              6     Tak    Tak         Dobry  10500.000000      651000
# 42             11     Tak    Tak  Bardzo dobry   9200.000000      552000
# 43              7     Tak    Nie         Dobry  10000.000000      550000
# 44              5     Tak    Tak         Dobry   9500.000000      617500
# 45              8     Tak    Tak         Dobry   8600.000000      653600

# %%
fig = plt.figure(figsize=(10, 5))
plt.ticklabel_format(style='plain')
plt.scatter(df["powierzchnia"], df["cena_total"])
plt.xlabel("Powierzchnia [m2]")
plt.ylabel("Cena [zł]")
plt.title("Stosunek powierzchni do ceny")
plt.show()

plt.title("Średnia cena za m2 w danym mieście")
plt.bar(df.sort_values(by='cena_m2', ascending=False)["miasto"], df.sort_values(by='cena_m2', ascending=False)["cena_m2"])
plt.show()
